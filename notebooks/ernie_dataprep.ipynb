# %% [markdown]
# # Data preparation and loading

# %% [markdown]
# 1. Load the `PhotoArt50`  and `Your Paintings` datasets
# 2. Add the 2 sets together
# 3. Identify number of works per class label

# %%
import pandas as pd
import os
import ssl
import urllib
import pathlib
from tqdm import tqdm
import logging
import traceback
# %load_ext autoreload

# %% [markdown]
# ## Download the paintings used in `Your Paintings`

# %%
df_yourpaintings = pd.read_csv("../raw_data/yourpaintings/painting_dataset_2021.csv")

# %%
df_yourpaintings.head()
# Out:
#                                            Image URL  \
# 0  https://d3d00swyhr67nd.cloudfront.net/w1200h12...
# 1  https://d3d00swyhr67nd.cloudfront.net/w1200h12...
# 2  https://d3d00swyhr67nd.cloudfront.net/w1200h12...
# 3  https://d3d00swyhr67nd.cloudfront.net/w1200h12...
# 4  https://d3d00swyhr67nd.cloudfront.net/w1200h12...
#
#                                         Web page URL   Subset    Labels
# 0  https://artuk.org/discover/artworks/and-the-co...   'test'    ' cow'
# 1  https://artuk.org/discover/artworks/0-6-00-6-0...  'train'  ' train'
# 2  https://artuk.org/discover/artworks/044t-locom...  'train'  ' train'
# 3  https://artuk.org/discover/artworks/080-locomo...   'test'  ' train'
# 4  https://artuk.org/discover/artworks/17th-and-2...   'test'  ' horse'

# %%
def get_your_paintings():
    PATH = pathlib.Path("../raw_data")
    yourpaintings_path = PATH/"yourpaintings"
    yourpaintings_path.mkdir(parents=True, exist_ok=True)
    urls = df_yourpaintings['Image URL'].tolist(); urls[:5]
    for url in urls[:5]:
        fname = url[url.rfind('/')+1:]
        print(fname)
    return urls, yourpaintings_path

urls, yourpaintings_path = get_your_paintings()
urls[:20]
print(yourpaintings_path)
# Out:
# NID_QUB_QUB_264-001.jpg
# GMIII_MOSI_A1978_72_3-001.jpg
# NY_NRM_1979_7964-001.jpg
# CHE_CRHC_PCF40-001.jpg
# NOT_NTMAG_1997_31-001.jpg
# ../raw_data/yourpaintings

# %%
def download(path, urls):
    # ignore SSL errors
    ssl._create_default_https_context = ssl._create_unverified_context
    for url in tqdm(urls):
        try:
            fname = url[url.rfind('/')+1:]
            urllib.request.urlretrieve(url, path/fname)
        except Exception as e:
            logging.error(traceback.format_exc())
            
download(yourpaintings_path, urls)
# Out:
#   2%|▋                                       | 152/8629 [00:11<15:13,  9.28it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   4%|█▋                                    | 383/8629 [04:38<2:37:24,  1.15s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   5%|█▊                                    | 412/8629 [05:09<2:50:44,  1.25s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   5%|██                                    | 459/8629 [06:06<2:40:18,  1.18s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   6%|██▏                                   | 484/8629 [06:33<2:16:54,  1.01s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   6%|██▍                                   | 544/8629 [07:45<2:46:49,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   7%|██▋                                   | 611/8629 [09:02<2:44:18,  1.23s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   8%|██▉                                   | 668/8629 [10:09<2:25:19,  1.10s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#   9%|███▌                                  | 805/8629 [13:03<2:51:27,  1.31s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  10%|███▉                                  | 905/8629 [15:15<2:55:39,  1.36s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  11%|████                                  | 931/8629 [15:47<3:18:46,  1.55s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  11%|████                                  | 936/8629 [15:52<2:36:40,  1.22s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  11%|████▏                                 | 956/8629 [16:16<2:42:56,  1.27s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  12%|████▍                                | 1022/8629 [17:42<2:31:59,  1.20s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  13%|████▉                                | 1157/8629 [20:37<2:28:00,  1.19s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  13%|████▉                                | 1161/8629 [20:41<2:06:13,  1.01s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  14%|████▉                                | 1165/8629 [20:43<1:37:39,  1.27it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  14%|█████                                | 1187/8629 [21:08<2:21:18,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  14%|█████▏                               | 1203/8629 [21:27<2:36:29,  1.26s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  15%|█████▌                               | 1283/8629 [23:04<3:07:14,  1.53s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  15%|█████▌                               | 1308/8629 [23:31<2:13:07,  1.09s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  15%|█████▋                               | 1321/8629 [23:45<2:31:53,  1.25s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  18%|██████▌                              | 1526/8629 [27:54<2:20:14,  1.18s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  18%|██████▌                              | 1530/8629 [27:57<1:59:26,  1.01s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#  18%|██████▌                              | 1541/8629 [28:09<2:27:11,  1.25s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  18%|██████▋                              | 1551/8629 [28:21<2:26:29,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  19%|██████▊                              | 1601/8629 [29:20<2:32:16,  1.30s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  19%|███████                              | 1641/8629 [30:07<2:20:29,  1.21s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  19%|███████                              | 1655/8629 [30:23<2:19:37,  1.20s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  19%|███████                              | 1657/8629 [30:25<1:57:49,  1.01s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  20%|███████▎                             | 1697/8629 [31:15<2:28:22,  1.28s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  20%|███████▎                             | 1703/8629 [31:21<2:13:49,  1.16s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  21%|███████▋                             | 1804/8629 [33:24<2:14:28,  1.18s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  21%|███████▋                             | 1807/8629 [33:26<1:56:03,  1.02s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  21%|███████▊                             | 1832/8629 [33:56<2:22:40,  1.26s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  21%|███████▉                             | 1846/8629 [34:11<2:16:18,  1.21s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  22%|████████                             | 1883/8629 [34:58<2:24:59,  1.29s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  22%|████████▏                            | 1895/8629 [35:10<2:19:57,  1.25s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  22%|████████▏                            | 1907/8629 [35:23<2:11:35,  1.17s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  23%|████████▍                            | 1976/8629 [36:50<2:09:02,  1.16s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  23%|████████▋                            | 2026/8629 [37:48<1:55:59,  1.05s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  24%|█████████                            | 2114/8629 [39:33<2:14:54,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  25%|█████████                            | 2122/8629 [39:41<2:03:33,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  25%|█████████▏                           | 2156/8629 [40:20<1:59:00,  1.10s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 7, in download
#     urllib.request.urlretrieve(url, path/fname)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1397, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1354, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1267, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1101, in putrequest
#     self._validate_path(url)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1201, in _validate_path
#     raise InvalidURL(f"URL can't contain control characters. {url!r} "
# http.client.InvalidURL: URL can't contain control characters. '/w800h800/collection/WYL/LU /WYL_LU_LMG_LU_132_30-001.jpg' (found at least ' ')
#  26%|█████████▋                           | 2265/8629 [42:29<2:11:00,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  27%|█████████▉                           | 2331/8629 [43:49<2:14:53,  1.29s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  28%|██████████▏                          | 2380/8629 [44:54<3:00:30,  1.73s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  28%|██████████▏                          | 2390/8629 [45:16<3:36:50,  2.09s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  28%|██████████▍                          | 2431/8629 [46:58<2:23:38,  1.39s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  28%|██████████▌                          | 2449/8629 [47:18<2:05:49,  1.22s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  30%|███████████▏                         | 2613/8629 [50:44<1:56:22,  1.16s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 7, in download
#     urllib.request.urlretrieve(url, path/fname)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1397, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1354, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1267, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1101, in putrequest
#     self._validate_path(url)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1201, in _validate_path
#     raise InvalidURL(f"URL can't contain control characters. {url!r} "
# http.client.InvalidURL: URL can't contain control characters. '/w800h800/collection/WYL/LU /WYL_LU_LMG_LU_143_04-001.jpg' (found at least ' ')
#
#  30%|███████████▏                         | 2617/8629 [50:47<1:28:52,  1.13it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  30%|███████████▎                         | 2626/8629 [50:56<1:52:57,  1.13s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  31%|███████████▎                         | 2641/8629 [51:13<1:48:30,  1.09s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  31%|███████████▎                         | 2649/8629 [51:21<1:53:05,  1.13s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  31%|███████████▍                         | 2654/8629 [51:27<1:58:25,  1.19s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  31%|███████████▍                         | 2662/8629 [51:35<1:59:23,  1.20s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  32%|███████████▊                         | 2756/8629 [53:46<2:02:17,  1.25s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  33%|████████████▎                        | 2857/8629 [55:48<1:57:36,  1.22s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  34%|████████████▋                        | 2947/8629 [57:37<1:43:00,  1.09s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  35%|████████████▉                        | 3007/8629 [58:47<1:46:55,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  36%|████████████▊                      | 3149/8629 [1:01:34<1:22:33,  1.11it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  37%|████████████▉                      | 3198/8629 [1:02:32<1:56:08,  1.28s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  38%|█████████████▏                     | 3256/8629 [1:03:41<2:05:04,  1.40s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#  39%|█████████████▋                     | 3361/8629 [1:05:58<1:55:26,  1.31s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  39%|█████████████▋                     | 3388/8629 [1:06:29<1:46:21,  1.22s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  40%|█████████████▊                     | 3415/8629 [1:07:03<1:49:49,  1.26s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  40%|██████████████                     | 3457/8629 [1:07:48<1:38:20,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  41%|██████████████▏                    | 3510/8629 [1:08:53<1:36:12,  1.13s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 7, in download
#     urllib.request.urlretrieve(url, path/fname)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1397, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1354, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1267, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1101, in putrequest
#     self._validate_path(url)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1201, in _validate_path
#     raise InvalidURL(f"URL can't contain control characters. {url!r} "
# http.client.InvalidURL: URL can't contain control characters. '/w800h800/collection/WYL/LU /WYL_LU_LMG_LU_089_23-001.jpg' (found at least ' ')
#
#  41%|██████████████▍                    | 3559/8629 [1:09:51<1:49:41,  1.30s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  42%|██████████████▊                    | 3655/8629 [1:11:45<1:36:54,  1.17s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  43%|██████████████▉                    | 3673/8629 [1:12:04<1:49:31,  1.33s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  43%|███████████████▏                   | 3753/8629 [1:13:40<1:45:52,  1.30s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  45%|███████████████▌                   | 3848/8629 [1:15:31<1:20:37,  1.01s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  45%|███████████████▋                   | 3856/8629 [1:15:40<1:29:09,  1.12s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  45%|███████████████▋                   | 3869/8629 [1:15:54<1:35:17,  1.20s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  46%|████████████████                   | 3959/8629 [1:17:38<1:29:17,  1.15s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  49%|█████████████████                  | 4216/8629 [1:22:41<1:06:35,  1.10it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  49%|█████████████████▎                 | 4253/8629 [1:23:25<1:38:24,  1.35s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  50%|█████████████████▎                 | 4278/8629 [1:23:57<1:22:36,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  51%|█████████████████▊                 | 4389/8629 [1:26:27<1:30:15,  1.28s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  51%|██████████████████                 | 4438/8629 [1:27:24<1:23:04,  1.19s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  51%|██████████████████                 | 4440/8629 [1:27:25<1:03:53,  1.09it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  52%|██████████████████                 | 4465/8629 [1:27:55<1:34:49,  1.37s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  52%|██████████████████▏                | 4484/8629 [1:28:17<1:09:10,  1.00s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  52%|██████████████████▏                | 4492/8629 [1:28:25<1:16:43,  1.11s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  52%|██████████████████▏                | 4494/8629 [1:28:26<1:01:59,  1.11it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  53%|██████████████████▋                | 4598/8629 [1:30:36<1:23:38,  1.25s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  54%|██████████████████▊                | 4639/8629 [1:31:27<1:25:55,  1.29s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  54%|██████████████████▉                | 4668/8629 [1:32:02<1:18:02,  1.18s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  55%|███████████████████▍               | 4788/8629 [1:34:30<1:15:27,  1.18s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  56%|███████████████████▋               | 4867/8629 [1:36:03<1:15:56,  1.21s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  57%|████████████████████               | 4953/8629 [1:37:42<1:09:30,  1.13s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  58%|████████████████████▎              | 5004/8629 [1:38:42<1:14:11,  1.23s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  59%|████████████████████▌              | 5078/8629 [1:40:12<1:14:31,  1.26s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  59%|████████████████████▋              | 5111/8629 [1:40:52<1:09:35,  1.19s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  59%|████████████████████▊              | 5119/8629 [1:41:00<1:09:20,  1.19s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  60%|████████████████████▊              | 5140/8629 [1:41:24<1:24:54,  1.46s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  60%|█████████████████████▏             | 5220/8629 [1:43:01<1:01:06,  1.08s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  63%|█████████████████████▉             | 5394/8629 [1:46:14<1:04:56,  1.20s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  63%|██████████████████████             | 5440/8629 [1:47:11<1:11:06,  1.34s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  65%|██████████████████████▌            | 5570/8629 [1:49:54<1:03:07,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  65%|██████████████████████▋            | 5597/8629 [1:50:24<1:02:50,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  65%|████████████████████████             | 5603/8629 [1:50:30<57:23,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 7, in download
#     urllib.request.urlretrieve(url, path/fname)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1397, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1354, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1267, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1101, in putrequest
#     self._validate_path(url)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1201, in _validate_path
#     raise InvalidURL(f"URL can't contain control characters. {url!r} "
# http.client.InvalidURL: URL can't contain control characters. '/w800h800/collection/WYL/LU /WYL_LU_LMG_LU_090_35-001.jpg' (found at least ' ')
#  66%|████████████████████████▎            | 5667/8629 [1:51:42<55:07,  1.12s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  66%|████████████████████████▌            | 5715/8629 [1:52:37<49:21,  1.02s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 7, in download
#     urllib.request.urlretrieve(url, path/fname)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1397, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1354, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1267, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1101, in putrequest
#     self._validate_path(url)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1201, in _validate_path
#     raise InvalidURL(f"URL can't contain control characters. {url!r} "
# http.client.InvalidURL: URL can't contain control characters. '/w800h800/collection/WYL/LU /WYL_LU_LMG_LU_090_08-001.jpg' (found at least ' ')
#
#  66%|████████████████████████▌            | 5736/8629 [1:52:59<57:26,  1.19s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  67%|████████████████████████▋            | 5749/8629 [1:53:11<55:54,  1.16s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  67%|████████████████████████▋            | 5761/8629 [1:53:24<53:16,  1.11s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  67%|███████████████████████▍           | 5791/8629 [1:53:59<1:02:47,  1.33s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  68%|█████████████████████████▏           | 5860/8629 [1:55:11<48:54,  1.06s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  69%|█████████████████████████▍           | 5946/8629 [1:56:47<57:19,  1.28s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  70%|████████████████████████▍          | 6010/8629 [1:58:20<1:47:27,  2.46s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ...
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  81%|█████████████████████████████▉       | 6970/8629 [2:22:55<40:53,  1.48s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  82%|██████████████████████████████▏      | 7049/8629 [2:24:57<36:29,  1.39s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  82%|██████████████████████████████▌      | 7116/8629 [2:26:37<35:13,  1.40s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  83%|██████████████████████████████▋      | 7145/8629 [2:27:18<31:27,  1.27s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  83%|██████████████████████████████▊      | 7192/8629 [2:28:22<31:07,  1.30s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  83%|██████████████████████████████▊      | 7198/8629 [2:28:28<28:23,  1.19s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  84%|██████████████████████████████▉      | 7219/8629 [2:28:57<37:18,  1.59s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  85%|███████████████████████████████▎     | 7292/8629 [2:30:40<30:58,  1.39s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  85%|███████████████████████████████▍     | 7331/8629 [2:31:34<32:47,  1.52s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  85%|███████████████████████████████▌     | 7367/8629 [2:32:19<26:01,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  85%|███████████████████████████████▋     | 7376/8629 [2:32:30<29:05,  1.39s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  86%|███████████████████████████████▉     | 7455/8629 [2:34:26<24:29,  1.25s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  87%|████████████████████████████████▏    | 7496/8629 [2:35:26<27:04,  1.43s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  87%|████████████████████████████████▎    | 7534/8629 [2:36:09<21:35,  1.18s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  87%|████████████████████████████████▎    | 7546/8629 [2:36:22<18:50,  1.04s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  88%|████████████████████████████████▋    | 7624/8629 [2:37:55<21:29,  1.28s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  89%|████████████████████████████████▊    | 7658/8629 [2:38:36<16:26,  1.02s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  90%|█████████████████████████████████▏   | 7749/8629 [2:40:19<17:04,  1.16s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#  90%|█████████████████████████████████▎   | 7759/8629 [2:40:30<16:38,  1.15s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  90%|█████████████████████████████████▍   | 7796/8629 [2:41:16<17:03,  1.23s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 7, in download
#     urllib.request.urlretrieve(url, path/fname)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 525, in open
#     response = self._open(req, data)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 542, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 502, in _call_chain
#     result = func(*args)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1397, in https_open
#     return self.do_open(http.client.HTTPSConnection, req,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/urllib/request.py", line 1354, in do_open
#     h.request(req.get_method(), req.selector, req.data, headers,
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1256, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1267, in _send_request
#     self.putrequest(method, url, **skips)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1101, in putrequest
#     self._validate_path(url)
#   File "/Users/enjiaochen/.pyenv/versions/3.8.12/lib/python3.8/http/client.py", line 1201, in _validate_path
#     raise InvalidURL(f"URL can't contain control characters. {url!r} "
# http.client.InvalidURL: URL can't contain control characters. '/w800h800/collection/WYL/LU /WYL_LU_LMG_LU_100_08-001.jpg' (found at least ' ')
#
#  91%|█████████████████████████████████▋   | 7854/8629 [2:42:24<16:33,  1.28s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  91%|█████████████████████████████████▋   | 7861/8629 [2:42:32<14:59,  1.17s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  91%|█████████████████████████████████▊   | 7880/8629 [2:42:52<15:25,  1.24s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  91%|█████████████████████████████████▊   | 7882/8629 [2:42:53<11:43,  1.06it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  92%|█████████████████████████████████▊   | 7899/8629 [2:43:11<15:32,  1.28s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  92%|█████████████████████████████████▉   | 7903/8629 [2:43:15<13:48,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  92%|█████████████████████████████████▉   | 7906/8629 [2:43:18<13:12,  1.10s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  92%|█████████████████████████████████▉   | 7926/8629 [2:43:39<13:05,  1.12s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  92%|██████████████████████████████████   | 7930/8629 [2:43:43<11:59,  1.03s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  92%|██████████████████████████████████   | 7932/8629 [2:43:44<09:48,  1.18it/s]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  92%|██████████████████████████████████   | 7953/8629 [2:44:08<15:03,  1.34s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  93%|██████████████████████████████████▎  | 8012/8629 [2:45:22<12:26,  1.21s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  95%|██████████████████████████████████▉  | 8155/8629 [2:48:06<09:31,  1.21s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  96%|███████████████████████████████████▍ | 8266/8629 [2:50:24<06:53,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  96%|███████████████████████████████████▍ | 8271/8629 [2:50:28<06:07,  1.03s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  96%|███████████████████████████████████▌ | 8307/8629 [2:51:06<06:17,  1.17s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  97%|███████████████████████████████████▋ | 8337/8629 [2:51:40<05:45,  1.18s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  97%|███████████████████████████████████▉ | 8376/8629 [2:52:23<04:28,  1.06s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  99%|████████████████████████████████████▊| 8572/8629 [2:56:07<01:28,  1.55s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  99%|████████████████████████████████████▊| 8574/8629 [2:56:08<01:00,  1.10s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
#  99%|████████████████████████████████████▊| 8577/8629 [2:56:12<00:59,  1.14s/it]ERROR:root:Traceback (most recent call last):
#   File "/var/folders/11/0smvrnys6yn2p6mvqskf9vxm0000gn/T/ipykernel_9714/3255119522.py", line 6, in download
#     fname = url[url.rfind('/')+1:]
# AttributeError: 'float' object has no attribute 'rfind'
#
# 100%|█████████████████████████████████████| 8629/8629 [2:57:14<00:00,  1.23s/it]

# %%
urls[:10]
print(type(urls))
mynewlist = [s for s in urls if s.isdigit()]

#for url in tqdm(urls):
#    fname = url[url.rfind('/')+1:]
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 urls[:10]
#       2 print(type(urls))
# ----> 3 mynewlist = [s for s in urls if s.isdigit()]
#
# Input In [11], in <listcomp>(.0)
#       1 urls[:10]
#       2 print(type(urls))
# ----> 3 mynewlist = [s for s in urls if s.isdigit()]
#
# AttributeError: 'float' object has no attribute 'isdigit'

# %% [markdown]
# ## Next let's standardise the set of classes to be classified
