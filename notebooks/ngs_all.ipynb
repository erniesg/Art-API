# %%
import pandas as pd
import pathlib
from tqdm import tqdm, tqdm_notebook
import urllib
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options

# %%
df = pd.read_csv('../raw_data/csv/collections.csv')

# %%
urls = df['img_url'].tolist(); urls[:5]
# Out:
# ['https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2013-00210_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/361958.2010-04541_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2014-01440_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2019-00086_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2013-00202_o3.jpg']

# %%
for url in urls[0:5]:
    fname = url[url.rfind('/')+1:]
    print(fname)
# Out:
# 2013-00210_o3.jpg
# 361958.2010-04541_o3.jpg
# 2014-01440_o3.jpg
# 2019-00086_o3.jpg
# 2013-00202_o3.jpg

# %%
urls
# Out:
# ['https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2013-00210_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/361958.2010-04541_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2014-01440_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2019-00086_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2013-00202_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/359514.2010-04109_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2003-03706_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/1999-00294_rephoto_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/2004-00621_o3.jpg',
#  'https://ngs-csp-prod.s3.ap-southeast-1.amazonaws.com/asset/Artwork/P-0616_o3.jpg',
# ...

# %%
fname_lst = []
for url in urls:
    fname = url[url.rfind('/')+1:]
    fname_lst.append(fname)    
df_comb = pd.concat([df, pd.DataFrame(fname_lst, columns = ['filename'])], ignore_index=True, axis=1)

# %%
df_comb.columns =['img_url', 'link_url', 'filename']

# %%
df_comb
# Out:
#                                                 img_url  \
# 0     https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 1     https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 2     https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 3     https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 4     https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# ...                                                 ...
# 7205  https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 7206  https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 7207  https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 7208  https://ngs-csp-prod.s3.ap-southeast-1.amazona...
# 7209  https://ngs-csp-prod.s3.ap-southeast-1.amazona...
#
#                                                link_url  \
# 0     https://collections.nationalgallery.sg/#/detai...
# 1     https://collections.nationalgallery.sg/#/detai...
# 2     https://collections.nationalgallery.sg/#/detai...
# 3     https://collections.nationalgallery.sg/#/detai...
# ...

# %%
for i in df_comb['link_url'].tolist()[0:1]:
    service = Service(ChromeDriverManager().install())

    options = Options()
  
    # this parameter tells Chrome that
    # it should be run without UI (Headless)
    options.headless = False

    # initializing webdriver for Chrome with our options
    #driver = webdriver.Chrome()

    service = Service(ChromeDriverManager().install())
    # driver = webdriver.Chrome(
    #     service=service,
    #     options=options
    # )
    options = Options()
    options.headless = True
    driver = webdriver.Chrome('/usr/local/bin/chromedriver', options=options)

    #driver = webdriver.Chrome(executable_path='../../../../chromedriver/stable', options=options)

    SLEEP_TIME = 10

    driver.get(i)
    print(f'got {i}')
    SLEEP_TIME = 15
    titles_element = driver.find_elements_by_xpath("//span[@class='ng-binding']")
    titles = [x.text for x in titles_element]
    titles = []
    for x in titles_element:
        titles.append(x.text)
    print(titles)
#     content = driver.find_element(By.XPATH, '//span[@class="ng-binding"][1]').text
#     print(content)


#'//span[@class="auto-link"][1]'

#    titles_element = driver.find_elements_by_class_name("ng-binding")
#    print(titles_element)
#     titles = [x.text for x in titles_element]
#     titles = []
#     for x in titles_element:
#         titles.append(x.text)
#     print(titles)
    #content = driver.find_element(By.CSS_SELECTOR, "span[ngbind-html='item.AccessionNo']").text
    #print(content)
    #element = driver.find_element_by_class_name(".ng-binding")
# Out:
# got https://collections.nationalgallery.sg/#/details/Home/22273
# []

# %%
for i in df_comb['link_url'].tolist()[0:1]:
    print(i)
# Out:
# https://collections.nationalgallery.sg/#/details/Home/22273
